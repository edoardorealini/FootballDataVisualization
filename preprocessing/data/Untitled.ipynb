# %%
import pandas as pd

data = pd.read_csv("pred_next10_fix_serieA.csv")

data
# Out:
#    fixture_id  home_team_id home_team_name  away_team_id away_team_name  \
# 0      608490           500        Bologna           523          Parma
# 1      608480           506      Benevento           505          Inter
# 2      608488           494        Udinese           515         Spezia
# 3      608484           487          Lazio           499       Atalanta
# 4      608502           502     Fiorentina           498      Sampdoria
# 5      608508           488       Sassuolo           501        Crotone
# 6      608503           495          Genoa           503         Torino
# 7      608509           494        Udinese           497        AS Roma
# 8      608500           499       Atalanta           490       Cagliari
# 9      608501           506      Benevento           500        Bologna
#
#   winning_percent_home winning_percent_draws winning_percent_away forme_home  \
# 0                  45%                   45%                  10%         0%
# ...
